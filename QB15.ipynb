# %% [markdown]
# # How many people in the EU quit smoking because of ecigs?
# * EU : Count the self reported quittters due to ecigs using eurobarometer 458 (2017)*
#
# ## Data sources
# * http://data.europa.eu/euodp/en/data/dataset/S2146_87_1_458_ENG
# * Something for the population counts.
#
# ## About/Context
# * **When this notebook first loads on nbviewer, all of the input cells are hidden. To reveal them, click the element tag icon in the top right of nbviewer. Click it again to hide them once more.**
# * *This is a Jupyter Notebook, all data and code is included. I love open science, this way of publishing has a lot of potential. The open data is aggregated, deep analisis is not possible, at best I can compare country behaviour.*

# %%
# %matplotlib inline
from mysetup import *;
import seaborn
from IPython.display import display, HTML

"""
Did ecigs help you quit smoking?
--
14:#QB15 You said that you smoke or used to smoke tobacco but also use, 
     used or tried electronic cigarettes or a similar device. 
    Did the use of electronic cigarettes or any similar device help you to stop or reduce your tobacco consumption? 

12:Yes, you stopped smoking tobacco completely
--
"""
# the data is badly structured, fix that first.
df = pandas.read_excel(A2PATH,sheet_name="QB15", header=7) # row 7 for correct headers.
display(toggleDisplay("all Questions in the sheet", df.iloc[:,1].to_frame("Q")))
data = df.iloc[[2,14],2:] # row 14 is the "yes" row, data starts at row 2.
# transpose & sort data
data = data.T.sort_values(by=14, ascending=False)
# Out:
# <script>
#     function toggle(el){
#         console.log(el)
#         var content = el.nextElementSibling;
#         if (content.style.display === "block") {
#           content.style.display = "none";
#           el.childNodes[1].textContent = " (+)"
#         } else {
#           content.style.display = "block";
#           el.childNodes[1].textContent = " (-)"
#         }
#     }
#     </script>
#
#     <button class="collapsible" onclick="toggle(this)">all Questions in the sheet<span> (+)</span></button>
#     <div class="content" style="display:none">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>TOTAL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Oui, vous avez complètement arrêté de fumer</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Yes, you stopped smoking tobacco completely</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Oui, vous avez arrêté de fumer pendant un temps, mais vous avez repris par la suite</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Yes, you stopped smoking tobacco for a while but then you started again</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Oui, vous avez réduit votre consommation de tabac, mais vous n'avez pas arrêté</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Yes, you reduced your tobacco consumption but you did not stop</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Non, vous n'avez pas du tout réduit votre consommation de tabac</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>No, you did not reduce your tobacco consumption at all</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Non, et en fait vous avez augmenté votre consommation de tabac</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>No, and you actually increased your tobacco consumption</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>NSP</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>DK</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Total 'Oui'</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Total 'Yes'</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Total 'Non'</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Total 'No'</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#     </div>

# %%
#Quit smokning using ecigs.
The UK leads the pack with 30% of ever users

# %%
ax = data.plot(kind="bar", figsize=[18,5])
ax.legend(["Yes, you stopped smoking tobacco completely",
           "Did the use of electronic cigarettes or any similar device help you to stop or reduce your tobacco consumption?"])

# %%
toggleDisplay("data",data)
# Out:
# <script>
#     function toggle(el){
#         console.log(el)
#         var content = el.nextElementSibling;
#         if (content.style.display === "block") {
#           content.style.display = "none";
#           el.childNodes[1].textContent = " (+)"
#         } else {
#           content.style.display = "block";
#           el.childNodes[1].textContent = " (-)"
#         }
#     }
#     </script>
#
#     <button class="collapsible" onclick="toggle(this)">data<span> (+)</span></button>
#     <div class="content" style="display:none">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2</th>
#       <th>14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>UK</th>
#       <td>0.3</td>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <th>IE</th>
#       <td>0.23</td>
#       <td>0.58</td>
#     </tr>
#     <tr>
#       <th>IT</th>
#       <td>0.17</td>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>HU</th>
#       <td>0.1</td>
#       <td>0.54</td>
#     </tr>
#     <tr>
#       <th>LU</th>
#       <td>0.09</td>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>BE</th>
#       <td>0.12</td>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>EL</th>
#       <td>0.11</td>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>PT</th>
#       <td>0.08</td>
#       <td>0.43</td>
#     </tr>
#     <tr>
#       <th>MT</th>
#       <td>0.08</td>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>UE28\nEU28</th>
#       <td>0.14</td>
#       <td>0.41</td>
#     </tr>
#     <tr>
#       <th>CY</th>
#       <td>0.04</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>D-W</th>
#       <td>0.12</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>FR</th>
#       <td>0.13</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>AT</th>
#       <td>0.09</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>NL</th>
#       <td>0.1</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>DK</th>
#       <td>0.18</td>
#       <td>0.39</td>
#     </tr>
#     <tr>
#       <th>CZ</th>
#       <td>0.09</td>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>DE</th>
#       <td>0.09</td>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>D-E</th>
#       <td>0.03</td>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>SK</th>
#       <td>0.11</td>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>FI</th>
#       <td>0.08</td>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>SE</th>
#       <td>0.2</td>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>BG</th>
#       <td>0.1</td>
#       <td>0.31</td>
#     </tr>
#     <tr>
#       <th>LT</th>
#       <td>0.1</td>
#       <td>0.3</td>
#     </tr>
#     <tr>
#       <th>EE</th>
#       <td>0.09</td>
#       <td>0.29</td>
#     </tr>
#     <tr>
#       <th>ES</th>
#       <td>0.07</td>
#       <td>0.28</td>
#     </tr>
#     <tr>
#       <th>LV</th>
#       <td>0.09</td>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <th>SI</th>
#       <td>0.12</td>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <th>PL</th>
#       <td>0.09</td>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>RO</th>
#       <td>0.03</td>
#       <td>0.15</td>
#     </tr>
#     <tr>
#       <th>HR</th>
#       <td>0.05</td>
#       <td>0.14</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#     </div>

# %% [markdown]
# 14% of ever-vapers in the EU stopped completely (self reported)
# what percentage tried vaping?
#
# ====
# *Perception of harm vs success?

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
